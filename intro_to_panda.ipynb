# %% [markdown]
# <a href="https://colab.research.google.com/github/ibnmikhail48/Learning-at-IT/blob/main/intro_to_panda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
cars = pd.Series(["BMW", "Toyota", "Honda"])

# %%
cars
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
# DataFrame = 2-dimensional and it makes use of python dictionary. it is far more common than seires
car_data = pd.DataFrame({"cars": cars, "colours": colours})
car_data
# Out:
#      cars colours
# 0     BMW     Red
# 1  Toyota    Blue
# 2   Honda   White

# %% [markdown]
# Importing Data

# %%
#Import Data
car_sales = pd.read_csv("car-sales.xls")
#pressing tabs show suggestion of the path of the data to be imported

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.head(10)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#anatomny of a DataFrame.
# row is referred to as axis o, while column is reffered to axis 1

# %%
#Exporting a dataFrame
#to is used to export a dataFrame either to csv or excel
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")

# %%
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
exported_car_sales.tail(4)
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors      Price
# 6           6   Honda   Blue          45698      4  $7,500.00
# 7           7   Honda   Blue          54738      4  $7,000.00
# 8           8  Toyota  White          60000      4  $6,250.00
# 9           9  Nissan  White          31600      4  $9,700.00

# %%
#The first import of data was possible because the file was in the same directory as the jupyter, but the second one is importing it from github,

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ## Describing data in Panda

# %%
# Attribute
car_sales.dtypes
# dtypes will show us the data type of each column name

#Function
#car_sales.mean()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
#.columns will list all column name
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns  #this will store the column name as list
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
#This show range data in the dataFrame
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
# .describe() gives statistical infor about dataFrame and it works on only numeric columns
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# info() bring information about the dataFrame, it conbine index with datatypes
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only = True)
#car_sale.mean() has been outdated because it cant work on string  while car_sales.mean(numeric_only = True) specifies the data type to work on which is int
# Out:
# Odometer (KM)     78601.4
# Doors                 4.0
# Price            764500.0
# dtype: float64

# %%
# .mean can also be used on Series
car_prices = pd.Series([3000, 4000, 5000])
car_prices.mean()
# Out:
# np.float64(4000.0)

# %%
# .sum add up all dataFrame, once numeric_only = True has been added it will only work on the integers
car_sales.sum(numeric_only = True)
# Out:
# Odometer (KM)     786014
# Doors                 40
# Price            7645000
# dtype: int64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price                                                      7645000
# dtype: object

# %%
#it can also work on a column name
car_sales["Doors"].sum()
# Out:
# np.int64(40)

# %%
car_sales['Colour'].sum()
# Out:
# 'WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite'

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales['Make'].sum()
# Out:
# 'ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyotaNissan'

# %%
#len is used to get the length of a DataFrame, that is the number of entries
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# .head() shows a quick information of the dataFrame and it always shows just five column unless specified
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7) #Specified
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail() #.tail() works just as .head() but it shows five rows from the bottom of the dataframe unless specified
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(4) #Specified
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"],  index = [1, 3, 5, 3, 9])

# %%
animals
# Out:
# 1      cat
# 3      dog
# 5     bird
# 3    panda
# 9    snake
# dtype: object

# %%
# .loc means location(index). it is used to get a particular index
animals.loc[3]
# Out:
# 3      dog
# 3    panda
# dtype: object

# %%
car_sales.loc[3]
# Out:
# Make                 BMW
# Colour             Black
# Odometer (KM)      11179
# Doors                  5
# Price            2200000
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#using python slicing
animals.iloc[:3]
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4  400000
# 1   Honda    Red          87899      4  500000
# 2  Toyota   Blue          32549      3  700000

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
#to select a particular column using column name
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Colour
# car_sales.Colour can get the same information as car_sales["Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# this code wont work because there is space between car_sales.Odometer (KM)

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
#Boolean indexing it used to specify part of column with a particular attribute
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4  400000
# 4  Nissan  White         213095      4  350000

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales[car_sales["Colour"] == "White"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales["Price"] == "$9,700.00"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## Viewing and Selecting data 2

# %%
# pd.crosstab is used to compare two columns
pd.crosstab(car_sales["Make"], car_sales["Doors"])
pd.crosstab(car_sales["Colour"], car_sales["Price"])
# Out:
# Price   350000   400000   450000   500000   625000   700000   750000   \
# Colour
# Black         0        0        0        0        0        0        0
# Blue          0        0        0        0        0        2        1
# Green         0        0        1        0        0        0        0
# Red           0        0        0        1        0        0        0
# White         1        1        0        0        1        0        0
#
# Price   970000   2200000
# Colour
# Black         0        1
# Blue          0        0
# Green         0        0
# Red           0        0
# White         1        0

# %%
import pandas as pd

# %%
 # Groupby. It seems this can only work on integers not other datatype
car_sales.groupby(["Make"]).mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors      Price
# Make
# BMW      11179.000000   5.00  2200000.0
# Honda    62778.333333   4.00   650000.0
# Nissan  122347.500000   4.00   660000.0
# Toyota   85451.250000   3.75   543750.0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.groupby(["Make"]).sum(numeric_only = True)
# Out:
#         Odometer (KM)  Doors    Price
# Make
# BMW             11179      5  2200000
# Honda          188335     12  1950000
# Nissan         244695      8  1320000
# Toyota         341805     15  2175000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales["Doors"].plot()
plt.show()

# %%
car_sales["Price"].hist()
plt.show()

# %%
car_sales["Price"].plot()
plt.show()

# %%
car_sales["Odometer (KM)"].plot()
plt.show()

# %%
car_sales["Odometer (KM)"].hist()
plt.show()

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_1208\908075715.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '', regex=True).astype(int)

# %%
car_sales["Price"].hist()
plt.show()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"].plot()
plt.show()

# %%
import pandas as pd

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# ## Manipulating data with Panda

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
## Changing a dataFrame requires re-assinging the data. For instance
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
## inplace parameter is used when there is a missing data.
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.head(15)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 7    Honda  White            NaN    4.0  20306.0
# 8      NaN  White       130538.0    4.0   9374.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13     NaN  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0

# %%
## .fillna() is used to fill missing data in panda
car_sales_missing["Odometer (KM)"].fillna(car_sales_missing["Odometer (KM)"].mean())
# Out:
# 0       35431.0
# 1      192714.0
# 2       84714.0
# 3      154365.0
# 4      181577.0
#          ...
# 995     35820.0
# 996    155144.0
# 997     66604.0
# 998    215883.0
# 999    248360.0
# Name: Odometer (KM), Length: 1000, dtype: float64

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.head(15)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White   35431.000000    4.0  15323.0
# 1      BMW   Blue  192714.000000    5.0  19943.0
# 2    Honda  White   84714.000000    4.0  28343.0
# 3   Toyota  White  154365.000000    4.0  13434.0
# 4   Nissan   Blue  181577.000000    3.0  14043.0
# 5    Honda    Red   42652.000000    4.0  23883.0
# 6   Toyota   Blue  163453.000000    4.0   8473.0
# 7    Honda  White  131253.237895    4.0  20306.0
# 8      NaN  White  130538.000000    4.0   9374.0
# 9    Honda   Blue   51029.000000    4.0  26683.0
# 10  Nissan  White  167421.000000    4.0  16259.0
# 11  Nissan  Green   17119.000000    4.0   6160.0
# 12  Nissan  White  102303.000000    4.0  16909.0
# 13     NaN  White  134181.000000    4.0  11121.0
# 14   Honda   Blue  199833.000000    4.0  18946.0

# %%
car_sales_missing["Make"] = car_sales_missing["Make"].fillna("Lexus")

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996   Lexus  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.head(15)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 7    Honda  White            NaN    4.0  20306.0
# 8    Lexus  White       130538.0    4.0   9374.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13   Lexus  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing_dropped
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996   Lexus  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [816 rows x 5 columns]

# %%
car_sales_missing_dropped.head(15)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %% [markdown]
# ## Manipulating Data with Panda 2

# %%
## creating data from an existing data
#Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])
seats_column
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
car_sales["Seats"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    NaN
# 6   honda   Blue          45698      4   750000    NaN
# 7   honda   Blue          54738      4   700000    NaN
# 8  toyota  White          60000      4   625000    NaN
# 9  nissan  White          31600      4   970000    NaN

# %%
car_sales["Seats"] = car_sales["Seats"].fillna(car_sales["Seats"].mean())

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   400000    5.0
# 1   honda    Red          87899      4   500000    5.0
# 2  toyota   Blue          32549      3   700000    5.0
# 3     bmw  Black          11179      5  2200000    5.0
# 4  nissan  White         213095      4   350000    5.0
# 5  toyota  Green          99213      4   450000    5.0
# 6   honda   Blue          45698      4   750000    5.0
# 7   honda   Blue          54738      4   700000    5.0
# 8  toyota  White          60000      4   625000    5.0
# 9  nissan  White          31600      4   970000    5.0

# %%
friends = pd.Series(["Salami", "Surajdeen", "Alliy", "Qudus", "Muhammed"])
friends
# Out:
# 0       Salami
# 1    Surajdeen
# 2        Alliy
# 3        Qudus
# 4     Muhammed
# dtype: object

# %%
car_sales["Eje"] = friends

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0        NaN
# 6   honda   Blue          45698      4   750000    5.0        NaN
# 7   honda   Blue          54738      4   700000    5.0        NaN
# 8  toyota  White          60000      4   625000    5.0        NaN
# 9  nissan  White          31600      4   970000    5.0        NaN

# %%
car_sales["Eje"] = car_sales["Eje"].fillna("Ejekeje")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 9  nissan  White          31600      4   970000    5.0    Ejekeje

# %%
#Column from Python list
fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 4.7, 7.6, 8.7, 3.0, 2.0]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM
# 0             7.5
# 1             9.2
# 2             5.0
# 3             9.6
# 4             8.7
# 5             4.7
# 6             7.6
# 7             8.7
# 8             3.0
# 9             2.0

# %%
car_sales["Fuel per 100KM"].mean()
# Out:
# np.float64(6.6)

# %%
car_sales["Total fuel used (L)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]
car_sales["Total fuel used (L)"]
# Out:
# 0    11253.225
# 1     8086.708
# 2     1627.450
# 3     1073.184
# 4    18539.265
# 5     4663.011
# 6     3473.048
# 7     4762.206
# 8     1800.000
# 9      632.000
# Name: Total fuel used (L), dtype: float64

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Total fuel used
# 0             7.5        11253.225
# 1             9.2         8086.708
# 2             5.0         1627.450
# 3             9.6         1073.184
# 4             8.7        18539.265
# ...

# %%
 ## Creating a new column from a single number
car_sales["Number of Wheels"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Total fuel used  Number of Wheels
# 0             7.5        11253.225                 4
# 1             9.2         8086.708                 4
# 2             5.0         1627.450                 4
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Total fuel used  Number of Wheels  Total fuel used (L)
# 0             7.5        11253.225                 4            11253.225
# 1             9.2         8086.708                 4             8086.708
# ...

# %%
car_sales["Passed road safety"] = True
car_sales.dtypes
# Out:
# Make                    object
# Colour                  object
# Odometer (KM)            int64
# Doors                    int64
# Price                    int64
# Seats                  float64
# Eje                     object
# Fuel per 100KM         float64
# Total fuel used        float64
# Number of Wheels         int64
# Total fuel used (L)    float64
# Passed road safety        bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Total fuel used  Number of Wheels  Total fuel used (L)  \
# 0             7.5        11253.225                 4            11253.225
# 1             9.2         8086.708                 4             8086.708
# ...

# %%
## To remove a particular column
car_sales = car_sales.drop("Total fuel used", axis=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Number of Wheels  Total fuel used (L)  Passed road safety
# 0             7.5                 4            11253.225                True
# 1             9.2                 4             8086.708                True
# ...

# %%
car_sales.plot()
plt.show()

# %%
car_sales.hist()
plt.show()

# %% [markdown]
# ## Manipulatind Data in Panda 3

# %%
#Sample is a way to shuffle data, used in data validation and testing in data science
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 0  toyota  White         150043      4   400000    5.0     Salami
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
#
#    Fuel per 100KM  Number of Wheels  Total fuel used (L)  Passed road safety
# 3             9.6                 4             1073.184                True
# 8             3.0                 4             1800.000                True
# ...

# %%
# When working on large data, only shuffle 20% of the data for easier access
car_sales_shuffle.sample(frac = 0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats        Eje  \
# 1   honda    Red          87899      4  500000    5.0  Surajdeen
# 8  toyota  White          60000      4  625000    5.0    Ejekeje
#
#    Fuel per 100KM  Number of Wheels  Total fuel used (L)  Passed road safety
# 1             9.2                 4             8086.708                True
# 8             3.0                 4             1800.000                True

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 5  toyota  Green          99213      4   450000    5.0    Ejekeje
# 7   honda   Blue          54738      4   700000    5.0    Ejekeje
# 0  toyota  White         150043      4   400000    5.0     Salami
# 1   honda    Red          87899      4   500000    5.0  Surajdeen
# 4  nissan  White         213095      4   350000    5.0   Muhammed
# 2  toyota   Blue          32549      3   700000    5.0      Alliy
# 9  nissan  White          31600      4   970000    5.0    Ejekeje
# 8  toyota  White          60000      4   625000    5.0    Ejekeje
# 3     bmw  Black          11179      5  2200000    5.0      Qudus
# 6   honda   Blue          45698      4   750000    5.0    Ejekeje
#
#    Fuel per 100KM  Number of Wheels  Total fuel used (L)  Passed road safety
# 5             4.7                 4             4663.011                True
# 7             8.7                 4             4762.206                True
# ...

# %%
car_sales_shuffled.reset_index(drop=True, inplace = True)

# %%
car_sales_shuffled
# Out:
#    level_0  index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0        0      5  toyota  Green          99213      4   450000    5.0
# 1        1      7   honda   Blue          54738      4   700000    5.0
# 2        2      0  toyota  White         150043      4   400000    5.0
# 3        3      1   honda    Red          87899      4   500000    5.0
# 4        4      4  nissan  White         213095      4   350000    5.0
# 5        5      2  toyota   Blue          32549      3   700000    5.0
# 6        6      9  nissan  White          31600      4   970000    5.0
# 7        7      8  toyota  White          60000      4   625000    5.0
# 8        8      3     bmw  Black          11179      5  2200000    5.0
# 9        9      6   honda   Blue          45698      4   750000    5.0
#
#          Eje  Fuel per 100KM  Number of Wheels  Total fuel used (L)  \
# 0    Ejekeje             4.7                 4             4663.011
# ...

# %%
## Appling a function to a column
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x:x /1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White   58610.546875      4   400000    5.0     Salami
# 1   honda    Red   34335.546875      4   500000    5.0  Surajdeen
# 2  toyota   Blue   12714.453125      3   700000    5.0      Alliy
# 3     bmw  Black    4366.796875      5  2200000    5.0      Qudus
# 4  nissan  White   83240.234375      4   350000    5.0   Muhammed
# 5  toyota  Green   38755.078125      4   450000    5.0    Ejekeje
# 6   honda   Blue   17850.781250      4   750000    5.0    Ejekeje
# 7   honda   Blue   21382.031250      4   700000    5.0    Ejekeje
# 8  toyota  White   23437.500000      4   625000    5.0    Ejekeje
# 9  nissan  White   12343.750000      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Number of Wheels  Total fuel used (L)  Passed road safety  \
# 0             7.5                 4            11253.225                True
# 1             9.2                 4             8086.708                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats        Eje  \
# 0  toyota  White   58610.546875      4   400000    5.0     Salami
# 1   honda    Red   34335.546875      4   500000    5.0  Surajdeen
# 2  toyota   Blue   12714.453125      3   700000    5.0      Alliy
# 3     bmw  Black    4366.796875      5  2200000    5.0      Qudus
# 4  nissan  White   83240.234375      4   350000    5.0   Muhammed
# 5  toyota  Green   38755.078125      4   450000    5.0    Ejekeje
# 6   honda   Blue   17850.781250      4   750000    5.0    Ejekeje
# 7   honda   Blue   21382.031250      4   700000    5.0    Ejekeje
# 8  toyota  White   23437.500000      4   625000    5.0    Ejekeje
# 9  nissan  White   12343.750000      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Number of Wheels  Total fuel used (L)  Passed road safety  \
# 0             7.5                 4            11253.225                True
# 1             9.2                 4             8086.708                True
# ...

# %%
car_sales.rename(columns={"Odometer (KM)" : "Odometer (Miles)"}, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (Miles)  Doors    Price  Seats        Eje  \
# 0  toyota  White      58610.546875      4   400000    5.0     Salami
# 1   honda    Red      34335.546875      4   500000    5.0  Surajdeen
# 2  toyota   Blue      12714.453125      3   700000    5.0      Alliy
# 3     bmw  Black       4366.796875      5  2200000    5.0      Qudus
# 4  nissan  White      83240.234375      4   350000    5.0   Muhammed
# 5  toyota  Green      38755.078125      4   450000    5.0    Ejekeje
# 6   honda   Blue      17850.781250      4   750000    5.0    Ejekeje
# 7   honda   Blue      21382.031250      4   700000    5.0    Ejekeje
# 8  toyota  White      23437.500000      4   625000    5.0    Ejekeje
# 9  nissan  White      12343.750000      4   970000    5.0    Ejekeje
#
#    Fuel per 100KM  Number of Wheels  Total fuel used (L)  Passed road safety  \
# 0             7.5                 4            11253.225                True
# ...
